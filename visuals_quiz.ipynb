# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below.

# %%
# imports and load data
import pandas as pd
# %matplotlib inline
df = pd.read_csv('powerplant_data_edited.csv')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# Avg_Ambient_temp            9568 non-null float64
# Exhaust Vaccum              9568 non-null float64
# Ambient Pressure            9568 non-null float64
# Relative Humidity           9568 non-null float64
# Electrical_Energy_Output    9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.8 KB

# %%
# plot relationship between temperature and electrical output
df.plot(x='Avg_Ambient_temp',y='Electrical_Energy_Output', kind='scatter');

# %%
# plot distribution of humidity
df['Relative Humidity'].hist();
# or df['Relative Humidity'].plot(kind='hist);

# %%
# plot box plots for each variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
# Avg_Ambient_temp            9568 non-null float64
# Exhaust Vaccum              9568 non-null float64
# Ambient Pressure            9568 non-null float64
# Relative Humidity           9568 non-null float64
# Electrical_Energy_Output    9568 non-null float64
# dtypes: float64(5)
# memory usage: 373.8 KB

# %%
df['Avg_Ambient_temp'].plot(kind='Box');

# %%
df['Exhaust Vaccum'].plot(kind='Box');

# %%
df['Ambient Pressure'].plot(kind='Box');

# %%
df['Relative Humidity'].plot(kind='Box');

# %%
df['Electrical_Energy_Output'].plot(kind='Box');
